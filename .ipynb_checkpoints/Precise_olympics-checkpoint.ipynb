# %% [markdown]
# This is a non-guided project applying what i learned in my previous "olympics" ML project but now with a dataset 100 times bigger!

# %% [markdown]
# First we install all the things we'll need

# %%
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np

# %%
athletes = pd.read_csv("athlete_events.csv", index_col="ID")

# %%
athletes
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0           China
# 2                       A Lamusi   M  23.0   170.0    60.0           China
# 3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 135569                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
athletes[athletes.isnull().any(axis=1)]
athletes["Medal_Num"] = athletes["Medal"].replace(["Gold", "Silver", "Bronze"], int(1))

# %%
summer = athletes[athletes["Season"] == "Summer"]
winter = athletes[athletes["Season"] == "Winter"]

# %%
winter
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# ID
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 135569                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
summer
# Out:
#                                       Name Sex   Age  Height  Weight  \
# ID
# 1                                A Dijiang   M  24.0   180.0    80.0
# 2                                 A Lamusi   M  23.0   170.0    60.0
# 3                      Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4                     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 8       Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...                                    ...  ..   ...     ...     ...
# 135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ID
# ...

# %% [markdown]
# I divided the dataset in 2 parts, the winter and summer olympics, I'm Going to use the largest to train the model and then test it with the shortest dataset
# summer = 222,552 rows
# winter = 48,564 rows

# %%
numsummer = summer.copy()
numsummer = numsummer[numsummer["Height"].notna()]
numsummer["Sex"] = numsummer["Sex"].replace(["M", "F"], [1, 0])

# df['Field_2'] = df['Field_2'].apply(np.int64) 
numsummer
# Out:
#                                       Name  Sex   Age  Height  Weight  \
# ID
# 1                                A Dijiang    1  24.0   180.0    80.0
# 2                                 A Lamusi    1  23.0   170.0    60.0
# 8       Cornelia "Cor" Aalten (-Strannood)    0  18.0   168.0     NaN
# 8       Cornelia "Cor" Aalten (-Strannood)    0  18.0   168.0     NaN
# 12                       Jyri Tapani Aalto    1  31.0   172.0    70.0
# ...                                    ...  ...   ...     ...     ...
# 135565            Fernando scar Zylberberg    1  27.0   168.0    76.0
# 135566          James Francis "Jim" Zylker    1  21.0   175.0    75.0
# 135567        Aleksandr Viktorovich Zyuzin    1  24.0   183.0    72.0
# 135567        Aleksandr Viktorovich Zyuzin    1  28.0   183.0    72.0
# 135568              Olga Igorevna Zyuzkova    0  33.0   171.0    69.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ID
# ...
